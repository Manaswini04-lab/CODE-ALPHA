# %%
# CodeAlpha Task 3 - Task Automation with Python
## Email Address Extraction from a Text File

# %%
# Create a sample text file

text = """
Hello everyone.
Contact us at example@gmail.com
For support, email support@company.com
You can also reach admin@test.org
Thank you!
"""

with open("input.txt", "w") as file:
    file.write(text)

print("input.txt file created successfully!")
# Out:
# input.txt file created successfully!

# %%
import re

# Read the text file
with open("input.txt", "r") as file:
    text = file.read()

# Find all email addresses
emails = re.findall(r'[\w\.-]+@[\w\.-]+\.\w+', text)

# Save emails to another file
with open("emails.txt", "w") as file:
    for email in emails:
        file.write(email + "\n")

print("Email addresses extracted successfully!")
print("\nFound emails:")

for email in emails:
    print(email)
# Out:
# Email addresses extracted successfully!
#
# Found emails:
# example@gmail.com
# support@company.com
# admin@test.org

# %%
# Display the extracted emails

with open("emails.txt", "r") as file:
    print(file.read())
# Out:
# example@gmail.com
# support@company.com
# admin@test.org
